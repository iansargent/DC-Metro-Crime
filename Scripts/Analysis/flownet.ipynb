# %%
import osmnx as ox

G = ox.graph_from_place("Washington, District of Columbia, USA",
                        network_type="walk")

# Convert to GeoDataFrames if needed
#nodes, edges = ox.graph_to_gdfs(G)
